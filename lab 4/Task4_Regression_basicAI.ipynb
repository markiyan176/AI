# %% [markdown]
# ## Лабораторна робота 4. **REGRESSION** 📈

# %% [markdown]
# # Опис вибірки "Motorbike Ambulance Calls"

# %% [markdown]
# Аварії за участю мотоциклів та відповідні виклики швидкої допомоги сильно залежать від екологічних та сезонних умов, таких як погодні умови, опади, день тижня, сезон, година дня тощо. Дані збирались протягом двох років щогодини та потім співвідносилися з відповідною погодою та сезонністю.

# %% [markdown]
# Основні характеристики вибірки `motorbike_ambulance_calls.csv`:
#
#               - index: record index
#               - date : date
#               - season : season (1:springer, 2:summer, 3:fall, 4:winter)
#               - yr : year (0: 2011, 1:2012)
#               - mnth : month ( 1 to 12)
#               - hr : hour (0 to 23)
#               - holiday : whether day is holiday or not
#               - weekday : day of the week
#               - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
#               -  weathersit :
#                       - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#                       - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#                       - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#                       - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#               - temp : Normalized temperature in Celsius. The values are divided to 41 (max)
#               - atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
#               - hum: Normalized humidity. The values are divided to 100 (max)
#               - windspeed: Normalized wind speed. The values are divided to 67 (max)
#               - cnt: count of total ambulance calls

# %% [markdown]
# ## Імпорт необхідних бібліотек та завантаження даних

# %% [markdown]
# **Завдання 1** підготовка даних до опрацювання
#
# 1. завантажте вибірку `motorbike_ambulance_calls.csv`;
# 2. підключіть необхідні бібліотеки;
# 3. вивести основну статистичну інформацію по числовим змінним;
# 4. окремо вивести максимальні та мінімальні значення по всім змінним;
# 5. вивести розмірність датасету;

# %%
import pandas as pd
import numpy as np
import scipy as sc
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def get_data(data_path: str):
  data = pd.read_csv(data_path)
  return data

# %%
data = get_data("/content/sample_data/motorbike_ambulance_calls.csv")
data.describe()
# Out:
#             index            yr          mnth            hr       holiday  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      0.502561      6.537775     11.546752      0.028770
# std     5017.0295      0.500008      3.438776      6.914405      0.167165
# min        1.0000      0.000000      1.000000      0.000000      0.000000
# 25%     4345.5000      0.000000      4.000000      6.000000      0.000000
# 50%     8690.0000      1.000000      7.000000     12.000000      0.000000
# 75%    13034.5000      1.000000     10.000000     18.000000      0.000000
# max    17379.0000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# ...

# %%
print(data.min(), "\n")
print(data.max())
# Out:
# index              1
# date          1/1/11
# season        autumn
# yr                 0
# mnth               1
# hr                 0
# holiday            0
# weekday            0
# workingday         0
# weathersit         1
# temp            0.02
# atemp            0.0
# hum              0.0
# windspeed        0.0
# cnt                1
# dtype: object
#
# index          17379
# date          9/9/12
# season        winter
# yr                 1
# mnth              12
# hr                23
# holiday            1
# weekday            6
# workingday         1
# weathersit         4
# temp             1.0
# atemp            1.0
# hum              1.0
# windspeed     0.8507
# cnt              977
# dtype: object

# %%
data.shape
# Out:
# (17379, 15)

# %% [markdown]
# **Завдання 2** перевірити типи даних та перевірте кількість даних по кожній змінній.

# %%
print(data.dtypes)
data.count()
# Out:
# index           int64
# date           object
# season         object
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# cnt             int64
# dtype: object
# index         17379
# date          17379
# season        17379
# yr            17379
# mnth          17379
# hr            17379
# holiday       17379
# weekday       17379
# workingday    17379
# weathersit    17379
# temp          17379
# atemp         17379
# hum           17379
# windspeed     17379
# cnt           17379
# dtype: int64

# %% [markdown]
# **Завдання 3** пепевірте всі змінні на наявність пропусків.

# %%
print(data.isna().sum().any())
# Out:
# False

# %% [markdown]
# **Висновки з 1-3 завдання (детальні)**

# %% [markdown]
# 1.  У нас немає пропущених значень
# 2.  В цьому датасеті майже всі колонки мають числове значення, інт і флоат
# 3.  Максимальна швидкість вітру - 0.8507

# %% [markdown]
# **Завдання 4** перетворіть змінну `date` в **date type**. Визначте часові межі датасету.

# %%
def tranform_date(df: pd.DataFrame, date_col_name: str):
    df[date_col_name] = pd.to_datetime(df[date_col_name], errors='coerce')
    return df

data = tranform_date(df=data, date_col_name='date')
print(data['date'])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 17374   2012-12-31
# 17375   2012-12-31
# 17376   2012-12-31
# 17377   2012-12-31
# 17378   2012-12-31
# Name: date, Length: 17379, dtype: datetime64[ns]
# <ipython-input-44-f1bd6cbf8567>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col_name] = pd.to_datetime(df[date_col_name], errors='coerce')

# %%
def get_time_limits(data: pd.DataFrame):
    first_day = data['date'].min()
    last_day = data['date'].max()
    print(f"First day of dataset - {first_day}.\nLast day of dataset - {last_day}")

get_time_limits(data)
# Out:
# First day of dataset - 2011-01-01 00:00:00.
# Last day of dataset - 2012-12-31 00:00:00

# %% [markdown]
# наш датасет йде з 2011 до 2012 року. ми перевторюємо date в тип даних datetime для того щоб зручніше працювати та створювати графіки.

# %% [markdown]
# #Аналіз категоріальних змінних

# %% [markdown]
# **Завдання 5** виділити категоріальні змінні в окремий датасет

# %%
data_categorical = data[["season", "holiday", "weekday", "weathersit", "workingday"]].copy()
data_categorical
# Out:
#        season  holiday  weekday  weathersit  workingday
# 0      spring        0        6           1           0
# 1      spring        0        6           1           0
# 2      spring        0        6           1           0
# 3      spring        0        6           1           0
# 4      spring        0        6           1           0
# ...       ...      ...      ...         ...         ...
# 17374  spring        0        1           2           1
# 17375  spring        0        1           2           1
# 17376  spring        0        1           1           1
# 17377  spring        0        1           1           1
# 17378  spring        0        1           1           1
#
# [17379 rows x 5 columns]

# %% [markdown]
# **Завдання 6** перетворіть змінну `season` в числову шкалу.

# %%
def encode_season(data: pd.DataFrame):
  data['season'] = data['season'].astype('category').cat.codes
  return data

data_categorical = encode_season(data_categorical)
print(data_categorical['season'])
print(data_categorical['season'].unique())
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17374    1
# 17375    1
# 17376    1
# 17377    1
# 17378    1
# Name: season, Length: 17379, dtype: int8
# [1 2 0 3]

# %% [markdown]
# **Завдання 7** побудувати графіки `countplot` по всім категоріальним змінним

# %%
fig, ax = plt.subplots(2, 4, figsize=(20, 10))
for variable, subplot in zip(data_categorical.columns, ax.flatten()):
    sns.countplot(x=variable, data=data_categorical, ax=subplot, palette='magma', hue=variable, legend=False)
    subplot.set_title(variable)
    subplot.set_xlabel("")
    subplot.set_ylabel("Count")
    subplot.tick_params(axis='x')

for extra_subplot in ax.flatten()[len(data_categorical.columns):]:
    fig.delaxes(extra_subplot)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Висновки з 5-7 завдання (детальні)**

# %% [markdown]
# 1.  Ми відділяємо категоріальні змінні щоб легше з ними працювати та використовувати не весь датасет, а лиш кусок з потрібними даними
# 2. перетворили змінну season в числову шкалу, щоб у кожного сезону був свій індекс та можна було легше юзати їх на графіках
# 3. працюють багато відпочивають мало

# %% [markdown]
# #Аналіз числових змінних

# %% [markdown]
# **Завдання 8** виділити числові змінні в окремий датасет

# %%
print(data_categorical.dtypes)
print(data.dtypes)

data_numerical = data[["weekday", "hum", "windspeed", "temp", "cnt"]].copy()
data_numerical
# Out:
# season         int8
# holiday       int64
# weekday       int64
# weathersit    int64
# workingday    int64
# dtype: object
# index                  int64
# date          datetime64[ns]
# season                object
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# cnt                    int64
# dtype: object
#        weekday   hum  windspeed  temp  cnt
# 0            6  0.81     0.0000  0.24   16
# 1            6  0.80     0.0000  0.22   40
# 2            6  0.80     0.0000  0.22   32
# 3            6  0.75     0.0000  0.24   13
# 4            6  0.75     0.0000  0.24    1
# ...        ...   ...        ...   ...  ...
# 17374        1  0.60     0.1642  0.26  119
# ...

# %% [markdown]
# **Завдання 9** побудуйте гістограми розподілу по всім числовим змінним

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 10))

for variable, subplot in zip(data_numerical.columns, ax.flatten()):
    sns.histplot(data_numerical[variable], bins=30, kde=True, ax=subplot, color='blue')
    subplot.set_title(f"Histogram of {variable}")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Завдання 10** побудуйте гістограму розподілу цільової змінної та розрахуйте коефіціент нахилу

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['cnt'], bins=30, kde=True, color='blue')
plt.xlabel('Кількість (cnt)')
plt.ylabel('Частота')
plt.title('Гістограма розподілу cnt')
plt.show()

skewness = sc.stats.skew(data['cnt'])
print(f'Коефіцієнт асиметрії: {skewness:.2f}')
# Out:
# Коефіцієнт асиметрії: 1.28

# %% [markdown]
# **Висновки з 8-10 завдання (детальні)**

# %% [markdown]
# 1.   коефіцієнт асиметрії - 1.28. скошеність позитивна, тому що графік зосереджений на менших значеннях. тобто від 0-200 викликів найбільш ймовірні
# 2.   ми відділили числові змінні щоб теж легше працювати з ними
# 3.   у нас немає лінійних залежностей.

# %% [markdown]
# #Аналіз взаємозв'язків між числовими і категоріальними змінними

# %% [markdown]
# **Завдання 11** побудуйте графіки співвідношення `scatterplot` між всіма числовими змінними і цільовою змінною `cnt`

# %%
fig, ax = plt.subplots(2,2, figsize=(15, 10))
for var, subplot in zip(data_numerical, ax.flatten()):
    sns.scatterplot(x=var, y='cnt', data=data_numerical, ax=subplot, color='blue')
    subplot.set_title(f'Scatter Plot of cnt and {var}')
    subplot.set_ylabel('Count')

# %% [markdown]
# **Завдання 12** побудуйте графіки співвідношення `boxplot`[boxplot](https://matplotlib.org/stable/gallery/statistics/boxplot_demo.html) між категоріальними змінними і цільовою змінною `cnt`.

# %%
data_categorical = data[["season", "yr", "mnth", "holiday", "weekday", "weathersit", "workingday", "hr", "cnt"]].copy()
data_categorical = encode_season(data_categorical)

fig, ax = plt.subplots(2, 4, figsize=(20, 10))
for var, subplot in zip(data_categorical.drop('cnt', axis =1), ax.flatten()):
    sns.boxplot(x=var, y='cnt', data=data_categorical, ax=subplot, palette='magma', hue=var, legend=False)
    subplot.set_title(f'Scatter Plot of cnt and {var}')
    subplot.set_ylabel('Count')

# %% [markdown]
# **Висновки з 11-12 завдання (детальні)**

# %% [markdown]
# 1.   у 8 ранку та у 5-6 годині вечора найбільше викликів швидкої допомоги. схоже на те, що зранку люди їдуть на роботу а ввечері з роботи, а отже: пробки, аварії.
# 2.   маємо дуже багато аномалій
# 3.   влітку найменше аварій. можливо тому, що погода хороша.
# 4.   в 2012 році було більше аварій
# 5.   дуже рідко швидкість вітру була високою

# %% [markdown]
# **Завдання 13** Побудувати матрицю кореляції:
#
# 1.   Вирахувати кореляційні коефіціенти для набору данних за методом Пірсона
# 2.   Відобразити отриману матрицю коефіціентів у вигляді теплокарти
# 3.   Вирахувати кореляційні коефіціенти для набору данних за методом Спірмана
# 4.   Відобразити отриману матрицю коефіціентів у вигляді теплокарти
#
# 5. Описати отримані результати, спираючись на значення коефіціентів кореляції та пояснити в чому відмінність обраних методів.

# %%
correlation_matrix_pearson = data_numerical.corr(method='pearson')

plt.figure(figsize=(12, 7))
sns.heatmap(correlation_matrix_pearson, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9)
plt.title("Correlation Matrix")
plt.show()

correlation_matrix_pearson
# Out:
#             weekday       hum  windspeed      temp       cnt
# weekday    1.000000 -0.037158   0.011502 -0.001795  0.026900
# hum       -0.037158  1.000000  -0.290105 -0.069881 -0.322911
# windspeed  0.011502 -0.290105   1.000000 -0.023125  0.093234
# temp      -0.001795 -0.069881  -0.023125  1.000000  0.404772
# cnt        0.026900 -0.322911   0.093234  0.404772  1.000000

# %%
correlation_matrix_spearman = data_numerical.corr(method='spearman')

plt.figure(figsize=(12, 7))
sns.heatmap(correlation_matrix_spearman, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.xticks(fontsize=9, rotation=0)
plt.yticks(fontsize=9)
plt.title("Correlation Matrix")
plt.show()

correlation_matrix_spearman
# Out:
#             weekday       hum  windspeed      temp       cnt
# weekday    1.000000 -0.036598   0.009936 -0.005724  0.030297
# hum       -0.036598  1.000000  -0.293913 -0.055408 -0.359614
# windspeed  0.009936 -0.293913   1.000000 -0.009719  0.126629
# temp      -0.005724 -0.055408  -0.009719  1.000000  0.423330
# cnt        0.030297 -0.359614   0.126629  0.423330  1.000000

# %% [markdown]
# Лінійні залежності майже відсутні

# %% [markdown]
# **Завдання 14**
# 1. побудувати модель лінійної регресії:
# 2. видалити змінні, які НЕ є релевантними;
#
# 3. поділити вибірку на `train`, `test` та `validation` в пропорції `70/30`;
#
# 4. провести навчання моделі лінійної регресії;

# %% [markdown]
# 1. Для подальшої роботи з моделями для кожної категоріальної змінної ми створимо фіктивні змінні, щоб уникнути неправильного порядку категорій. [get_dummies](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html)

# %%
def get_dummies(df: pd.DataFrame):
    features = pd.concat([
        df,
        pd.get_dummies(df['season']),
        pd.get_dummies(df['mnth'], prefix='mnth'),
        pd.get_dummies(df['hr'], prefix='hr'),
        pd.get_dummies(df['weekday'], prefix='weekday'),
        pd.get_dummies(df['weathersit'], prefix='weathersit')
    ], axis=1)

    features = features.drop(['season', 'mnth', 'weekday', 'weathersit'], axis=1)

    return features

# %%
features = get_dummies(data)
features
# Out:
#        index       date  yr  hr  holiday  workingday  temp   atemp   hum  \
# 0          1 2011-01-01   0   0        0           0  0.24  0.2879  0.81
# 1          2 2011-01-01   0   1        0           0  0.22  0.2727  0.80
# 2          3 2011-01-01   0   2        0           0  0.22  0.2727  0.80
# 3          4 2011-01-01   0   3        0           0  0.24  0.2879  0.75
# 4          5 2011-01-01   0   4        0           0  0.24  0.2879  0.75
# ...      ...        ...  ..  ..      ...         ...   ...     ...   ...
# 17374  17375 2012-12-31   1  19        0           1  0.26  0.2576  0.60
# 17375  17376 2012-12-31   1  20        0           1  0.26  0.2576  0.60
# 17376  17377 2012-12-31   1  21        0           1  0.26  0.2576  0.60
# 17377  17378 2012-12-31   1  22        0           1  0.26  0.2727  0.56
# 17378  17379 2012-12-31   1  23        0           1  0.26  0.2727  0.65
#
#        windspeed  ...  weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  \
# ...

# %% [markdown]
# 2. На основі змінної часу створіть нову змінну, яка відповідатиме за день і ніч.

# %%
def is_night_hour(hour):
    return hour < 6 or hour >= 23

def add_night_hours_feature(df):
    df['night_hours'] = df['hr'].map(is_night_hour)
    return df.drop(columns=['hr'])

features = add_night_hours_feature(features)
features['night_hours'] = features['night_hours'].astype(int)
features
# Out:
#        index       date  yr  holiday  workingday  temp   atemp   hum  \
# 0          1 2011-01-01   0        0           0  0.24  0.2879  0.81
# 1          2 2011-01-01   0        0           0  0.22  0.2727  0.80
# 2          3 2011-01-01   0        0           0  0.22  0.2727  0.80
# 3          4 2011-01-01   0        0           0  0.24  0.2879  0.75
# 4          5 2011-01-01   0        0           0  0.24  0.2879  0.75
# ...      ...        ...  ..      ...         ...   ...     ...   ...
# 17374  17375 2012-12-31   1        0           1  0.26  0.2576  0.60
# 17375  17376 2012-12-31   1        0           1  0.26  0.2576  0.60
# 17376  17377 2012-12-31   1        0           1  0.26  0.2576  0.60
# 17377  17378 2012-12-31   1        0           1  0.26  0.2727  0.56
# 17378  17379 2012-12-31   1        0           1  0.26  0.2727  0.65
#
#        windspeed  cnt  ...  weekday_2  weekday_3  weekday_4  weekday_5  \
# ...

# %% [markdown]
# **Модель лінійної регрессії
#
# [train_linear_model](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %% [markdown]
# Після отримання фіктивних змінних потрібно видалити по одній з кожної категорії, щоб запобігти мультиколінеарності. Також видаляємо ще два атрибути `date` та `atemp` - поясніть чому?

# %%
features_lr = features.drop(['spring', 'mnth_4', 'weekday_0', 'weathersit_1', 'hr_0','atemp', 'date'], axis = 1)

# %%
def get_train_data(df: pd.DataFrame, target: str, test_size: float):
    X = df.drop(columns=[target])
    y = df[target]

    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=42, shuffle=True
    )

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = get_train_data(features_lr, 'cnt', 0.3)

# %%
def train_linear_model(X_train, y_train):
  model = LinearRegression()
  model.fit(X_train, y_train)
  return model

model = train_linear_model(X_train, y_train)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print('MSE train: {:.3f}, test: {:.3f}'.format(
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_test, y_test_pred)))
print('R^2 train: {:.3f}, test: {:.3f}'.format(
        r2_score(y_train, y_train_pred),
        r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 10448.098, test: 10101.710
# R^2 train: 0.688, test: 0.680

# %% [markdown]
# Оскільки в нашій моделі є багато незалежних змінних, ми не можемо відобразити їх залежність у двовимірному просторі, але ми можемо побудувати графік взаємозв'язку між залишками моделі та передбачуваними значеннями, що також допоможе нам оцінити якість моделі.

# %%
plt.scatter(y_train_pred,  y_train_pred - y_train,
            c='#5f93ad', marker='o', label='Training data')
plt.scatter(y_test_pred,  y_test_pred - y_test,
            c='#98c3d9', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0, xmin=-220, xmax=1000, lw=2, color='#000000')
plt.tight_layout()

# %% [markdown]
# **Висновки з завдання (детальні)**

# %% [markdown]
# 1.   Лінійні зв'язки майже відсутні
# 2.   Було закодовано категоріальні ознаки та створено night_hours
# 3.   Було видалено корельовані ознаки за для зменшення мультиколінеарності
# 4.   Лінійна регресія: 70% даних, 30% — тестування по завданню
# 5.   Високий R^2 і низький MSE отже хороша модель
# 6.   Залишки випадкові
